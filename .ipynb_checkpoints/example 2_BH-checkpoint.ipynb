# %%
import torch
import torch.nn as nn
import numpy as np
import random                                                                  
import matplotlib.pyplot as plt
torch.backends.cudnn.deterministic=True
from torch.nn import functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import math
from torch.autograd import grad
from Libraries import robotarm as ra
from Libraries import ICNN_net as netZ
from Libraries import ICNN_plot as pl
from Libraries import ICNN_optim as opt
dtype = torch.float
device_c = torch.device("cpu")
device = torch.device("cuda:0")

# %%
#robot initialize
l1 = 3 
l2 = 2
m1 = 3
m2 = 4
robot = ra.robotarm(l1,l2,m1,m2,device)
xinit = torch.tensor([[-3],[0]],dtype=dtype)
xfinal = torch.tensor([[3],[2.5]],dtype=dtype)
T = 5
delta = 0.6
num_timesteps = 100
rmin,rmax,qmin,qmax,dt,qinit,qfinal,Xstable,xtraj,x_dot,qtraj,q_dot = robot.Initialize(xinit,xfinal,T,delta,num_timesteps)
#print(max_speed)
#ICNN initialize
V_hidden_sizes = [200, 200]
fhat_hidden_sizes = [2000,2000,2000]
tol = 0.01
alpha = 0.1
#model = net.ICNN_net( V_hidden_sizes, fhat_hidden_sizes,tol,alpha)

# %%
#optimization

#getting grid data (for the regularizer)
nq1 = 100 # grid number
nq2 = 100 
nq1_b = 10 # grid number
nq2_b = 10
penalty = 50000
penalty_boundary = 10000
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device) #qmin, qmax는 위에서 구함
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)
q_in_boundary,q_dot_boundary = optim_.get_boundary(nq1_b,nq2_b,qmin,qmax)

# %%
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 1276, loss = 2.858023, loss_b = 0.32456648, loss_t = 2.7526796                    .

# %%
nq1_p = 100
nq2_p = 100
nx1 = 100
nx2 = 100
xmin = [-robot.l1-robot.l2, -robot.l2]
xmax = [robot.l1+robot.l2,robot.l1+robot.l2]
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,l1,l2,device)

# %%
plt_.plot_f('fplot.png', 2, 0.5, 1, quiver = False, streamplot = True)

# %%
plt_.plot_f_taskspace('task_plot.png', robot, 2, 0.5, 1, quiver = False, streamplot = True)
# Out:
# /home/robotics/iPython_Notebook_Program/LeeByeongho/Harmonic_Regularizer/Harmonic_Regularization/Libraries/ICNN_plot.py:102: RuntimeWarning: invalid value encountered in arccos
#   q1 = np.arccos(((self.l1+self.l2*np.cos(q2))*x1+(self.l2*np.sin(q2))*x2)/(self.l1**2+self.l2**2+2*self.l1*self.l2*np.cos(q2)))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-7893594818c0> in <module>
# ----> 1 plt_.plot_f_taskspace('task_plot.png', robot, 2, 0.5, 1, quiver = False, streamplot = True)
#
# ~/iPython_Notebook_Program/LeeByeongho/Harmonic_Regularizer/Harmonic_Regularization/Libraries/ICNN_plot.py in plot_f_taskspace(self, filename, robot, density, widthscale, widthbase, quiver, streamplot, cmax)
#     333
#     334             strm = plt.streamplot(self.x1_mesh.t().numpy(), self.x2_mesh.t().numpy(), np.transpose(U), np.transpose(V), density = density ,color =color,linewidth = width,
# --> 335                                   cmap='autumn')
#     336             plt.colorbar(strm.lines)
#     337             if(cmax):
#
# ~/anaconda3/envs/py3_bhl/lib/python3.6/site-packages/matplotlib/pyplot.py in streamplot(x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, maxlength, integration_direction, data)
#    2935         maxlength=maxlength,
#    2936         integration_direction=integration_direction, **({"data": data}
# -> 2937         if data is not None else {}))
#    2938     sci(__ret.lines)
#    2939     return __ret
#
# ~/anaconda3/envs/py3_bhl/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/py3_bhl/lib/python3.6/site-packages/matplotlib/streamplot.py in streamplot(axes, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, maxlength, integration_direction)
#      84         changes should be backward compatible.
#      85     """
# ---> 86     grid = Grid(x, y)
#      87     mask = StreamMask(density)
#      88     dmap = DomainMap(grid, mask)
#
# ~/anaconda3/envs/py3_bhl/lib/python3.6/site-packages/matplotlib/streamplot.py in __init__(self, x, y)
#     344
#     345         if not np.allclose(np.diff(x), self.width / (self.nx - 1)):
# --> 346             raise ValueError("'x' values must be equally spaced")
#     347         if not np.allclose(np.diff(y), self.height / (self.ny - 1)):
#     348             raise ValueError("'y' values must be equally spaced")
#
# ValueError: 'x' values must be equally spaced

# %%
plt_.cal_f()
fnumpy = plt_.f_total.detach()
#xtraj = robot.task_trajectory(robot.xinit, robot.xfinal, robot.T, robot.delta, robot.num_timesteps)
theta = np.linspace(0,2*math.pi,num = 100)
x_r1 = (l1-l2)*np.cos(theta)
y_r1 = (l1-l2)*np.sin(theta)
x_r2 = (l1+l2)*np.cos(theta)
y_r2 = (l1+l2)*np.sin(theta)
x_r3 = (l2)*np.cos(theta)+l1
y_r3 = (l2)*np.abs(np.sin(theta))
x_r4 = (l2)*np.cos(theta)-l1
y_r4 = -(l2)*np.abs(np.sin(theta))
if (l1-l2)>0:
    plt.plot(x_r1,y_r1,'--b')
plt.plot(x_r2,y_r2,'--b')
plt.plot(x_r3,y_r3,'y')
plt.plot(x_r4,y_r4,'y')

plt.rcParams["figure.figsize"] = (15,15)
plt.plot((xinit.numpy()[0],xfinal.numpy()[0]),(xinit.numpy()[1],xfinal.numpy()[1]),'g')
#x1_mesh,x2_mesh = torch.meshgrid(xtraj[0,:],xtraj[1,:])
#widths = 0.002
plt.axis([-(l1+l2), (l1+l2), -(l1+l2), (l1+l2)])
#plt.quiver(xtraj[0,:],xtraj[1,:],x_dot[0,:],x_dot[1,:],width=0.003)
#plt.savefig('x.png',dpi = 200)

q1_mesh = plt_.q1_mesh
q2_mesh = plt_.q2_mesh
x1_mesh = np.zeros(q1_mesh.shape)
x2_mesh = np.zeros(q1_mesh.shape)
x_1_dot = np.zeros(q1_mesh.shape)
x_2_dot = np.zeros(q1_mesh.shape)

for i in range(q1_mesh.shape[0]):
    for j in range(q1_mesh.shape[1]):
        temp = robot.forward_kinematics([q1_mesh[i,j],q2_mesh[i,j]])
        temp2 = np.matmul(robot.get_jacobian([q1_mesh[i,j],q2_mesh[i,j]]),fnumpy[i,j,:])
        x1_mesh[i,j] = temp[0]
        x2_mesh[i,j] = temp[1]
        x_1_dot[i,j] = temp2[0]
        x_2_dot[i,j] = temp2[1]

plt.quiver(x1_mesh,x2_mesh,x_1_dot,x_2_dot,color = 'r',width=0.002)
#plt.streamplot(x1_mesh,x2_mesh,x_1_dot,x_2_dot,density = 3)#,
                       #color = np.log(x_1_dot*x_1_dot+x_2_dot*x_2_dot))

# %%
plt_.plot_fhat('fhatplot.png', quiver = False, streamplot = True)

# %%
plt_.plot_V('Vplot.png')
