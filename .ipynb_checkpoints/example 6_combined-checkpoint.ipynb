# %%
import torch
import torch.nn as nn
import numpy as np
import random                                                                  
import matplotlib.pyplot as plt
torch.backends.cudnn.deterministic=True
from torch.nn import functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import math
from torch.autograd import grad
from Libraries import robotarm as ra
from Libraries import ICNN_net as net
from Libraries import ICNN_plot as pl
from Libraries import ICNN_optim_custom_penalty as opt
dtype = torch.float
device_c = torch.device("cpu")
device = torch.device("cuda:0")

# %%
#robot initialize
l1 = 3 
l2 = 2
m1 = 3
m2 = 4
robot = ra.robotarm(l1,l2,m1,m2,device)
xinit = torch.tensor([[-2],[2]],dtype=dtype)
#xinit = torch.tensor([[0],[3]],dtype=dtype)
xfinal = torch.tensor([[3],[3]],dtype=dtype)
#xinit = torch.tensor([[-3],[0]],dtype=dtype)
#xfinal = torch.tensor([[3],[2.5]],dtype=dtype)
T = 3
delta = 0.6
num_timesteps = 100
xpoints = np.array([  2.5,1.5,1 ,1.5,2.5])
ypoints = np.array([  0.5,1  ,1.5,2  ,2.5])
#rmin,rmax,qmin,qmax,dt,qinit,qfinal,Xstable,xtraj,x_dot,qtraj,q_dot = robot.Initialize(xinit,xfinal,T,delta,num_timesteps)
rmin,rmax,qmin,qmax,dt,qinit,qfinal,Xstable,xtraj,qtraj,q_dot = robot.Initialize_spline(xpoints,ypoints, T, delta, num_timesteps)

#ICNN initialize
fhat_size = 500
V_size = 200
V_hidden_sizes = [V_size, V_size,V_size,V_size]
fhat_hidden_sizes = [fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size]
tol = 0.01
alpha = 0.01
#getting grid data (for the regularizer)
nq1 = 100 # grid number
nq2 = 100 
nq1_b = 10 # grid number
nq2_b = 10
penalty = 5000
penalty_boundary = 100000
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device) #qmin, qmax는 위에서 구함
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)
q_in_boundary,q_dot_boundary = optim_.get_boundary(nq1_b,nq2_b,qmin,qmax)
nq1_p = 100
nq2_p = 100
nx1 = 100
nx2 = 100
xmin = [-robot.l1-robot.l2, -robot.l2]
xmax = [robot.l1+robot.l2,robot.l1+robot.l2]

# %% [markdown]
# # Ploting trajectory

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_q_traj('qtraj.png')

# %%
theta1 = xpoints[2]
theta2 = ypoints[2]
plt_.plot_robot_taskspace('robotplot.png', robot,theta1,theta2, traj=True)

# %% [markdown]
# # No Regularization

# %%
# initialize
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 57, loss = 0.7964803, loss_b = 0.22787058, loss_t = 0.7445553                    . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-e694a5401bcc> in <module>
# ----> 1 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     158         for t in range(epoch):
#     159
# --> 160             qdot_bound_pred = self.model.f_forward(q_in_boundary,self.Xstable).to(self.device)
#     161             temp0_boundary = torch.sqrt((qdot_bound_pred**2)[:,0]+(qdot_bound_pred**2)[:,1])
#     162             temp_boundary = torch.mul(q_dot_boundary,qdot_bound_pred)
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in f_forward(self, X, Xstable)
#     163
#     164         Vsum = torch.sum(torch.sum(V))
# --> 165         gradV = grad(Vsum,X,create_graph=True,retain_graph=True)[0]
#     166         Vnorm0 = gradV ** 2
#     167         Vnorm = torch.zeros(V.shape,dtype=dtype,device=self.device)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     155     return Variable._execution_engine.run_backward(
#     156         outputs, grad_outputs, retain_graph, create_graph,
# --> 157         inputs, allow_unused)
#     158
#     159
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# ## weight norm decay

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
# Out:
#  epoch = 4531, loss = 0.002905826, loss_b = 0.0, loss_t = 0.002905826                    . .        .. ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-8186a0ffa40f> in <module>
#       1 #####################################################################
#       2 #weight regularization
# ----> 3 optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_weight_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch, weight_decay)
#     209
#     210             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 211             loss.backward(retain_graph=True)
#     212             optimizer.step()
#     213             q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# # Euclidean Regularization

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 1850, loss = 0.009934039, loss_b = 0.0, loss_t = 0.009934039                    . .      ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-954352254adf> in <module>
#       1 #no regularization
# ----> 2 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     170
#     171             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 172             loss.backward(retain_graph=True)
#     173             optimizer.step()
#     174             q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
# Out:
#  epoch = 10000, loss = 0.0029787044, loss_b = 0.0, loss_t = 0.0029787044                    .     . ...

# %%
#optimization for Euclidean regularizer
#mode 0: exp barrier, 1: relu squared
optim_.optim_Euc_reg(q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, learning_rate = 1e-3,epoch=100, batch_size = 40,penalty_mode = 0)
# Out:
#  epoch = 20 i = 77, loss = 5613.065, total_loss = 5615.753, loss_b = 0.0, loss_t = 0.06424581, loss_reg = 40.08749, loss_reg_total =  34.352314           .....     ......
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f785c9be4b2c> in <module>
#       1 #optimization for Euclidean regularizer
#       2 #mode 0: exp barrier, 2: relu squared
# ----> 3 loss_mat = optim_.optim_Euc_reg(q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, learning_rate = 1e-3,epoch=100, batch_size = 40,penalty_mode = 0)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_Euc_reg(self, q_in_reg, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, penalty, penalty_boundary, learning_rate, epoch, batch_size, penalty_mode)
#     354
#     355                 #print(loss)
# --> 356                 loss.backward(retain_graph=True)
#     357                 optimizer.step()
#     358                 q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# # Kinematic Regularization

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 45, loss = 2.6486595, loss_b = 0.32743138, loss_t = 2.541448                    ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-954352254adf> in <module>
#       1 #no regularization
# ----> 2 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     170
#     171             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 172             loss.backward(retain_graph=True)
#     173             optimizer.step()
#     174             q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=1000,weight_decay = 1e-4)
# Out:
#  epoch = 1818, loss = 0.008646962, loss_b = 0.0004328127, loss_t = 0.008646775                    ....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-8186a0ffa40f> in <module>
#       1 #####################################################################
#       2 #weight regularization
# ----> 3 optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_weight_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch, weight_decay)
#     205
#     206
# --> 207             qdot_pred = self.model.f_forward(q_in,self.Xstable).to(self.device)
#     208             loss_traj = dt*loss_fn(qdot_pred,qdot_real).to(self.device)
#     209
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in f_forward(self, X, Xstable)
#     158     def f_forward(self, X, Xstable):
#     159         V = self.V_forward(X, Xstable)
# --> 160         f_hat = self.fhat_forward(X)
#     161         f = torch.zeros(f_hat.shape)
#     162
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in fhat_forward(self, X)
#     141         fhat_z4 = self.fhat_activation(fhat_z4_pre)
#     142         fhat_z5_pre = self.fhatl5(fhat_z4)
# --> 143         fhat_z5 = self.fhat_activation(fhat_z5_pre)
#     144         #fhat_z6_pre = self.fhatl5(fhat_z5)
#     145         #fhat_z6 = self.fhat_activation(fhat_z6_pre)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\activation.py in forward(self, input)
#     533
#     534     def forward(self, input):
# --> 535         return F.leaky_relu(input, self.negative_slope, self.inplace)
#     536
#     537     def extra_repr(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py in leaky_relu(input, negative_slope, inplace)
#    1061         result = torch._C._nn.leaky_relu_(input, negative_slope)
#    1062     else:
# -> 1063         result = torch._C._nn.leaky_relu(input, negative_slope)
#    1064     return result
#    1065
#
# KeyboardInterrupt:

# %%
#optimization for Euclidean regularizer
#mode 0: exp barrier, 1: relu squared
optim_.optim_Kinematic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 4e-4,epoch=150, batch_size = 40,penalty_mode = 0)
# Out:
#  epoch = 0 i = 20, loss = 1755718.1, total_loss = 1162860.0, loss_b = 1.3644402, loss_t = 2.884545, loss_reg = 23.57316, loss_reg_total =  25.11682           . ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c39fd103410a> in <module>
#       1 #optimization for Euclidean regularizer
#       2 #mode 0: exp barrier, 1: relu squared
# ----> 3 optim_.optim_Kinematic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 4e-4,epoch=150, batch_size = 40,penalty_mode = 0)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_Kinematic_reg(self, robot, q_in_reg, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, penalty, penalty_boundary, Xstable, learning_rate, epoch, batch_size, penalty_mode)
#     496                 eps = 0.01
#     497                 loss = loss_reg+penalty*(self.penalty_fun(loss_task,mode = penalty_mode))+penalty_boundary*((loss_boundary)**2)
# --> 498                 loss.backward(retain_graph=True)
#     499                 optimizer.step()
#     500                 q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# # Kinetic Regularization

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 30, loss = 3.0239146, loss_b = 0.18863001, loss_t = 2.9883332                    ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-954352254adf> in <module>
#       1 #no regularization
# ----> 2 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     174             q_in.grad.zero_()
#     175             q_in_boundary.grad.zero_()
# --> 176             self.model.zero_grad()
#     177             optimizer.zero_grad()
#     178             ld = loss.data.clone().to(device_c)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in zero_grad(self)
#    1106             if p.grad is not None:
#    1107                 p.grad.detach_()
# -> 1108                 p.grad.zero_()
#    1109
#    1110     def share_memory(self):
#
# KeyboardInterrupt:

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
# Out:
#  epoch = 519, loss = 0.00926117, loss_b = 0.0, loss_t = 0.00926117                    . . .       ..

# %%
#optimization for Euclidean regularizer
#mode 0: exp barrier, 1: relu squared
optim_.optim_Kinetic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 1e-3,epoch=100, batch_size = 40,penalty_mode = 0)
# Out:
#  epoch = 0 i = 137, loss = nan, total_loss = nan, loss_b = nan, loss_t = nan, loss_reg = nan, loss_reg_total =  nan           .         .1518           ..

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %%
nq1_p = 100
nq2_p = 100
nx1 = 100
nx2 = 100
xmin = [-robot.l1-robot.l2, -robot.l2]
xmax = [robot.l1+robot.l2,robot.l1+robot.l2]
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)

# %%
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)

# %%
plt_.plot_V('t.png',3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8ea4d4481998> in <module>
# ----> 1 plt_.plot_V('t.png',3)
#
# ~\Harmonic_Regularization\Libraries\ICNN_plot.py in plot_V(self, filename, num_level)
#     295     def plot_V(self, filename,num_level):
#     296         pi = math.pi
# --> 297         V_total = self.cal_V()
#     298
#     299
#
# ~\Harmonic_Regularization\Libraries\ICNN_plot.py in cal_V(self)
#     148         Xlong = self.qmesh.view(-1,2).to(self.device)
#     149         Xlong.requires_grad=True
# --> 150         V_long = self.model.fh_forward(Xlong, self.Xstable)
#     151         V_total = V_long.view(self.nq1,self.nq2).to(device_c).detach()
#     152         #for i in range(self.nq1):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#     583                 return modules[name]
#     584         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 585             type(self).__name__, name))
#     586
#     587     def __setattr__(self, name, value):
#
# AttributeError: 'ICNN_net' object has no attribute 'fh_forward'
