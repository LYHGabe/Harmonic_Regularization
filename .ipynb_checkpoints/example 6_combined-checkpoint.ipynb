# %%
import torch
import torch.nn as nn
import numpy as np
import random                                                                  
import matplotlib.pyplot as plt
torch.backends.cudnn.deterministic=True
from torch.nn import functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import math
from torch.autograd import grad
from Libraries import robotarm as ra
from Libraries import ICNN_net as net
from Libraries import ICNN_plot as pl
from Libraries import ICNN_optim_custom_penalty as opt
dtype = torch.float
device_c = torch.device("cpu")
device = torch.device("cuda:0")

# %%
#robot initialize
l1 = 0.3 
l2 = 0.2
m1 = 3
m2 = 2
robot = ra.robotarm(l1,l2,m1,m2,device)
xinit = torch.tensor([[-2],[2]],dtype=dtype)
#xinit = torch.tensor([[0],[3]],dtype=dtype)
xfinal = torch.tensor([[3],[3]],dtype=dtype)
#xinit = torch.tensor([[-3],[0]],dtype=dtype)
#xfinal = torch.tensor([[3],[2.5]],dtype=dtype)
T = 3
delta = 0.6
num_timesteps = 100
xpoints = np.array([  1.0,0.6,0.5,0.6,1.0])
ypoints = np.array([  1.5,1.7,1.9,2.3,2.6])
Vpoints = np.array([1.5,1.7,1.9,2.3,2.6])
#rmin,rmax,qmin,qmax,dt,qinit,qfinal,Xstable,xtraj,x_dot,qtraj,q_dot = robot.Initialize(xinit,xfinal,T,delta,num_timesteps)
rmin,rmax,qmin,qmax,dt,qinit,qfinal,Xstable,xtraj,qtraj,q_dot = robot.Initialize_spline(xpoints,ypoints,Vpoints, T, delta, num_timesteps)

#ICNN initialize
fhat_size = 1000
V_size = 300
V_hidden_sizes = [V_size, V_size]
fhat_hidden_sizes = [fhat_size,fhat_size]
tol = 0.01
alpha = 0.01
#getting grid data (for the regularizer)
nq1 = 100 # grid number
nq2 = 100 
nq1_b = 10 # grid number
nq2_b = 10
penalty = 5000
penalty_boundary = 100000
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device) #qmin, qmax는 위에서 구함
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)
q_in_boundary,q_dot_boundary = optim_.get_boundary(nq1_b,nq2_b,qmin,qmax)
nq1_p = 100
nq2_p = 100
nx1 = 100
nx2 = 100
xmin = [-robot.l1-robot.l2, -robot.l2]
xmax = [robot.l1+robot.l2,robot.l1+robot.l2]

# %% [markdown]
# # Ploting trajectory

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_q_traj('qtraj.png')

# %%
theta1 = xpoints[2]
theta2 = ypoints[2]
plt_.plot_robot_taskspace('robotplot.png', robot,theta1,theta2, traj=True)

# %% [markdown]
# # No Regularization

# %%
# initialize
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 2120, loss = 0.0014437848, loss_b = 0.0, loss_t = 0.0014437848                    .       ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e694a5401bcc> in <module>
# ----> 1 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     172
#     173             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 174             loss.backward(retain_graph=True)
#     175             optimizer.step()
#     176             q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)
# Out:
# C:\Users\BHLee-robotics\Harmonic_Regularization\Libraries\ICNN_plot.py:103: RuntimeWarning: invalid value encountered in arccos
#   q1 = np.arccos(((self.l1+self.l2*np.cos(q2))*x1+(self.l2*np.sin(q2))*x2)/(self.l1**2+self.l2**2+2*self.l1*self.l2*np.cos(q2)))

# %% [markdown]
# ## weight norm decay

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 156, loss = 0.007306448, loss_b = 0.0, loss_t = 0.007306448                    . .  ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-954352254adf> in <module>
#       1 #no regularization
# ----> 2 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     172
#     173             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 174             loss.backward(retain_graph=True)
#     175             optimizer.step()
#     176             q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
# Out:
#  epoch = 10000, loss = 0.0009814985, loss_b = 0.0011922073, loss_t = 0.0009800772                    ...

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# # Euclidean Regularization

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 699, loss = 0.0007015482, loss_b = 0.0, loss_t = 0.0007015482                    . .  .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-954352254adf> in <module>
#       1 #no regularization
# ----> 2 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     173             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
#     174             loss.backward(retain_graph=True)
# --> 175             optimizer.step()
#     176             q_in.grad.zero_()
#     177             q_in_boundary.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\optim\adam.py in step(self, closure)
#      93
#      94                 # Decay the first and second moment running average coefficient
# ---> 95                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
#      96                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      97                 if amsgrad:
#
# KeyboardInterrupt:

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-4 ,epoch=10000,weight_decay = 1e-4)
# Out:
#  epoch = 106, loss = 0.00056326756, loss_b = 0.0, loss_t = 0.00056326756                    .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e0dee57ac97f> in <module>
#       1 #####################################################################
#       2 #weight regularization
# ----> 3 optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-4 ,epoch=10000,weight_decay = 1e-4)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_weight_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch, weight_decay)
#     211
#     212             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 213             loss.backward(retain_graph=True)
#     214             optimizer.step()
#     215             q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
#optimization for Euclidean regularizer
#mode 0: exp barrier, 1: relu squared
mode = 2
optim_.optim_Euc_reg(q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, learning_rate = 5e-5,epoch=100, batch_size = 40,penalty_mode = mode)
# Out:
#  epoch = 10 i = 242, loss = 5774.3506, total_loss = 5772.992, loss_b = 0.0, loss_t = 0.00052024843, loss_reg = 4.8478765, loss_reg_total =  3.4850802           ..    . . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b8da35e35389> in <module>
#       2 #mode 0: exp barrier, 1: relu squared
#       3 mode = 2
# ----> 4 optim_.optim_Euc_reg(q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, learning_rate = 5e-5,epoch=100, batch_size = 40,penalty_mode = mode)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_Euc_reg(self, q_in_reg, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, penalty, penalty_boundary, learning_rate, epoch, batch_size, penalty_mode)
#     345                 loss_reg = torch.sum(qdot_grad_norm)*self.dA/2*(self.nq1*self.nq2/batch_size)
#     346
# --> 347                 qdot_pred = self.model.f_forward(q_in,self.Xstable).to(self.device)
#     348                 loss_task = dt*loss_fn(qdot_pred,qdot_real).to(self.device)
#     349                 ##################
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in f_forward(self, X, Xstable)
#     157
#     158     def f_forward(self, X, Xstable):
# --> 159         V = self.V_forward(X, Xstable)
#     160         f_hat = self.fhat_forward(X)
#     161         f = torch.zeros(f_hat.shape)
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in V_forward(self, X, Xstable)
#     114         V_z1_pre = self.Vl1(X-Xstable)
#     115         V_z1 = self.Smooth_ReLU(V_z1_pre)
# --> 116         V_z2_pre = self.Vl2(X-Xstable,V_z1)
#     117         V_z2 = self.Smooth_ReLU(V_z2_pre)
#     118         #V_z3_pre = self.Vl3(X-Xstable,V_z2)
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# # Kinematic Regularization

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 258, loss = 0.005959592, loss_b = 0.0, loss_t = 0.005959592                    . .       .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-954352254adf> in <module>
#       1 #no regularization
# ----> 2 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     160         for t in range(epoch):
#     161
# --> 162             qdot_bound_pred = self.model.f_forward(q_in_boundary,self.Xstable).to(self.device)
#     163             temp0_boundary = torch.sqrt((qdot_bound_pred**2)[:,0]+(qdot_bound_pred**2)[:,1])
#     164             temp_boundary = torch.mul(q_dot_boundary,qdot_bound_pred)
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in f_forward(self, X, Xstable)
#     158     def f_forward(self, X, Xstable):
#     159         V = self.V_forward(X, Xstable)
# --> 160         f_hat = self.fhat_forward(X)
#     161         f = torch.zeros(f_hat.shape)
#     162
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in fhat_forward(self, X)
#     136         fhat_z2_pre = self.fhatl2(fhat_z1)
#     137         fhat_z2 = self.fhat_activation(fhat_z2_pre)
# --> 138         fhat_z3_pre = self.fhatl3(fhat_z2)
#     139         fhat_z3 = self.fhat_activation(fhat_z3_pre)
#     140         fhat_z4_pre = self.fhatl4(fhat_z3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-4 ,epoch=1000,weight_decay = 1e-4)
# Out:
#  epoch = 801, loss = 0.00031313286, loss_b = 0.0, loss_t = 0.00031313286                    .         ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-05ccb6a8de08> in <module>
#       1 #####################################################################
#       2 #weight regularization
# ----> 3 optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-4 ,epoch=1000,weight_decay = 1e-4)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_weight_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch, weight_decay)
#     207
#     208
# --> 209             qdot_pred = self.model.f_forward(q_in,self.Xstable).to(self.device)
#     210             loss_traj = dt*loss_fn(qdot_pred,qdot_real).to(self.device)
#     211
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in f_forward(self, X, Xstable)
#     157
#     158     def f_forward(self, X, Xstable):
# --> 159         V = self.V_forward(X, Xstable)
#     160         f_hat = self.fhat_forward(X)
#     161         f = torch.zeros(f_hat.shape)
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in V_forward(self, X, Xstable)
#     117         V_z2 = self.Smooth_ReLU(V_z2_pre)
#     118         V_z3_pre = self.Vl3(X-Xstable,V_z2)
# --> 119         V_z3 = self.Smooth_ReLU(V_z3_pre)
#     120         V_z4_pre = self.Vl4(X-Xstable,V_z3)
#     121         V_z4 = self.Smooth_ReLU(V_z4_pre)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\activation.py in forward(self, input)
#      92
#      93     def forward(self, input):
# ---> 94         return F.relu(input, inplace=self.inplace)
#      95
#      96     def extra_repr(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py in relu(input, inplace)
#     912         result = torch.relu_(input)
#     913     else:
# --> 914         result = torch.relu(input)
#     915     return result
#     916
#
# KeyboardInterrupt:

# %%
#optimization for Euclidean regularizer
#mode 0: exp barrier, 1: relu squared
optim_.optim_Kinematic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 3e-5,epoch=150, batch_size = 40,penalty_mode = 2)
# Out:
#  epoch = 2 i = 105, loss = 5768.4424, total_loss = 5768.587, loss_b = 0.0, loss_t = 0.00047472952, loss_reg = 0.08315551, loss_reg_total =  0.21730085           . .      . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-baed73f63aa7> in <module>
#       1 #optimization for Euclidean regularizer
#       2 #mode 0: exp barrier, 1: relu squared
# ----> 3 optim_.optim_Kinematic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 3e-5,epoch=150, batch_size = 40,penalty_mode = 2)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_Kinematic_reg(self, robot, q_in_reg, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, penalty, penalty_boundary, Xstable, learning_rate, epoch, batch_size, penalty_mode)
#     475                 Matrix_G_inv = torch.zeros(2*num_sampled_batch,2*num_sampled_batch).to(self.device)
#     476                 for k in range(num_sampled_batch):
# --> 477                     Temp1 = robot.get_Christoffel_kinematic(current_grid_data[k,:])
#     478                     Temp2 = robot.get_Kinematic_Riemannian_metric(current_grid_data[k,:])
#     479
#
# ~\Harmonic_Regularization\Libraries\robotarm.py in get_Christoffel_kinematic(self, q)
#      63
#      64     def get_Christoffel_kinematic(self, q):
# ---> 65         G = self.get_Kinematic_Riemannian_metric(q)
#      66         G_inv = torch.inverse(G)
#      67         Gamma_1 = 0.5*G_inv.matmul(torch.tensor([[0, -2*self.l1*self.l2*torch.sin(q[1])],
#
# ~\Harmonic_Regularization\Libraries\robotarm.py in get_Kinematic_Riemannian_metric(self, q)
#      56     def get_Kinematic_Riemannian_metric(self, q):
#      57         Kinematic_Riemannian_metric = torch.tensor([[0,0],[0,0]], dtype=torch.float32)
# ---> 58         Jacobian = self.get_jacobian(q)
#      59         Jacobian_transpose = Jacobian.t()
#      60         Kinematic_Riemannian_metric = torch.mm(Jacobian_transpose,Jacobian)
#
# ~\Harmonic_Regularization\Libraries\robotarm.py in get_jacobian(self, q)
#      51         Jacobian[1,0] = self.l1*torch.cos(q[0])+self.l2*torch.cos(q[0]+q[1])
#      52         Jacobian[0,1] = -self.l2*torch.sin(q[0]+q[1])
# ---> 53         Jacobian[1,1] = self.l2*torch.cos(q[0]+q[1])
#      54         return Jacobian
#      55
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# # Kinetic Regularization

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 5357, loss = 0.00067470147, loss_b = 0.0, loss_t = 0.00067470147                    .  .. ..  ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-954352254adf> in <module>
#       1 #no regularization
# ----> 2 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     172
#     173             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 174             loss.backward(retain_graph=True)
#     175             optimizer.step()
#     176             q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
# Out:
#  epoch = 1145, loss = 0.0002940032, loss_b = 0.0, loss_t = 0.0002940032                    . .     .....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-8186a0ffa40f> in <module>
#       1 #####################################################################
#       2 #weight regularization
# ----> 3 optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_weight_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch, weight_decay)
#     207
#     208
# --> 209             qdot_pred = self.model.f_forward(q_in,self.Xstable).to(self.device)
#     210             loss_traj = dt*loss_fn(qdot_pred,qdot_real).to(self.device)
#     211
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in f_forward(self, X, Xstable)
#     157
#     158     def f_forward(self, X, Xstable):
# --> 159         V = self.V_forward(X, Xstable)
#     160         f_hat = self.fhat_forward(X)
#     161         f = torch.zeros(f_hat.shape)
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in V_forward(self, X, Xstable)
#     114         V_z1_pre = self.Vl1(X-Xstable)
#     115         V_z1 = self.Smooth_ReLU(V_z1_pre)
# --> 116         V_z2_pre = self.Vl2(X-Xstable,V_z1)
#     117         V_z2 = self.Smooth_ReLU(V_z2_pre)
#     118         V_z3_pre = self.Vl3(X-Xstable,V_z2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in forward(self, X, z)
#      49     def forward(self, X, z):
#      50
# ---> 51         out = self.icnnx(X) + self.icnnz(z)
#      52
#      53         return out
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# KeyboardInterrupt:

# %%
#optimization for Euclidean regularizer
#mode 0: exp barrier, 1: relu squared
optim_.optim_Kinetic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 5e-5,epoch=100, batch_size = 40,penalty_mode = 2)
# Out:
#  epoch = 3 i = 57, loss = 11532.971, total_loss = 11533.375, loss_b = 0.0, loss_t = 0.00039645116, loss_reg = 0.18396221, loss_reg_total =  0.551786           ......     .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-14c86fd07afb> in <module>
#       1 #optimization for Euclidean regularizer
#       2 #mode 0: exp barrier, 1: relu squared
# ----> 3 optim_.optim_Kinetic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 3e-5,epoch=100, batch_size = 40,penalty_mode = 2)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_Kinetic_reg(self, robot, q_in_reg, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, penalty, penalty_boundary, Xstable, learning_rate, epoch, batch_size, penalty_mode)
#     648
#     649
# --> 650                 qdot_pred = self.model.f_forward(q_in,Xstable).to(self.device)
#     651                 loss_task = dt*loss_fn(qdot_pred,qdot_real).to(self.device)
#     652                 penalty = 10000                             ##########################################################################
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in f_forward(self, X, Xstable)
#     157
#     158     def f_forward(self, X, Xstable):
# --> 159         V = self.V_forward(X, Xstable)
#     160         f_hat = self.fhat_forward(X)
#     161         f = torch.zeros(f_hat.shape)
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in V_forward(self, X, Xstable)
#     120         #V_z4_pre = self.Vl4(X-Xstable,V_z3)
#     121         #V_z4 = self.Smooth_ReLU(V_z4_pre)
# --> 122         V_zf_pre = self.Vlf(X-Xstable,V_z2)
#     123         V_zf = self.Smooth_ReLU(V_zf_pre)
#     124
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in forward(self, X, z)
#      49     def forward(self, X, z):
#      50
# ---> 51         out = self.icnnx(X) + self.icnnz(z)
#      52
#      53         return out
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %%
nq1_p = 100
nq2_p = 100
nx1 = 100
nx2 = 100
xmin = [-robot.l1-robot.l2, -robot.l2]
xmax = [robot.l1+robot.l2,robot.l1+robot.l2]
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)

# %%
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)

# %%
plt_.plot_V('t.png',3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8ea4d4481998> in <module>
# ----> 1 plt_.plot_V('t.png',3)
#
# ~\Harmonic_Regularization\Libraries\ICNN_plot.py in plot_V(self, filename, num_level)
#     295     def plot_V(self, filename,num_level):
#     296         pi = math.pi
# --> 297         V_total = self.cal_V()
#     298
#     299
#
# ~\Harmonic_Regularization\Libraries\ICNN_plot.py in cal_V(self)
#     148         Xlong = self.qmesh.view(-1,2).to(self.device)
#     149         Xlong.requires_grad=True
# --> 150         V_long = self.model.fh_forward(Xlong, self.Xstable)
#     151         V_total = V_long.view(self.nq1,self.nq2).to(device_c).detach()
#     152         #for i in range(self.nq1):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#     583                 return modules[name]
#     584         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 585             type(self).__name__, name))
#     586
#     587     def __setattr__(self, name, value):
#
# AttributeError: 'ICNN_net' object has no attribute 'fh_forward'
