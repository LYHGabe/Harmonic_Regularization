# %%
import torch
import torch.nn as nn
import numpy as np
import random                                                                  
import matplotlib.pyplot as plt
torch.backends.cudnn.deterministic=True
from torch.nn import functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import math
from torch.autograd import grad
from Libraries import robotarm as ra
from Libraries import ICNN_net as net
from Libraries import ICNN_plot as pl
from Libraries import ICNN_optim_custom_penalty as opt
dtype = torch.float
device_c = torch.device("cpu")
device = torch.device("cuda:0")

# %%
#robot initialize
l1 = 3 
l2 = 2
m1 = 3
m2 = 4
robot = ra.robotarm(l1,l2,m1,m2,device)
#xinit = torch.tensor([[-2],[1]],dtype=dtype)
#xfinal = torch.tensor([[-2.3],[0.7]],dtype=dtype)
xinit = torch.tensor([[-3],[1]],dtype=dtype)
xfinal = torch.tensor([[2],[3]],dtype=dtype)
T = 5
delta = 0.6
num_timesteps = 100
rmin,rmax,qmin,qmax,dt,qinit,qfinal,Xstable,xtraj,x_dot,qtraj,q_dot = robot.Initialize(xinit,xfinal,T,delta,num_timesteps)
#spline adopting

xpoints = np.array([   -2,  -3,  -1,  0 ,1,  2])
ypoints = np.array([   1 ,   2,   3,  2 ,3,  3])
xtraj,x_dot = robot.spline_traj(xpoints,ypoints, T, delta, num_timesteps)
qtraj = robot.config_trajectory(xtraj)
q_dot = robot.config_velocity(qtraj,x_dot)

#ICNN initialize
fhat_size = 500
V_size = 200
V_hidden_sizes = [V_size, V_size,V_size,V_size]
fhat_hidden_sizes = [fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size]
tol = 0.01
alpha = 0.1
#model = net.ICNN_net( V_hidden_sizes, fhat_hidden_sizes,tol,alpha,device)

# %%
###################################################################
#getting grid data (for the regularizer)
nq1 = 100 # grid number
nq2 = 100 
nq1_b = 10 # grid number
nq2_b = 10
penalty = 5000
penalty_boundary = 100000
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device,slope = 0.01) #qmin, qmax는 위에서 구함
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)
q_in_boundary,q_dot_boundary = optim_.get_boundary(nq1_b,nq2_b,qmin,qmax)

# %%
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=3000)
# Out:
#  epoch = 649, loss = 0.0041534095, loss_b = 0.0, loss_t = 0.0041534095                    .     ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e7f05e626722> in <module>
# ----> 1 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=3000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     166
#     167
# --> 168             qdot_pred = self.model.f_forward(q_in,self.Xstable).to(self.device)
#     169             loss_traj = dt*loss_fn(qdot_pred,qdot_real).to(self.device)
#     170
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in f_forward(self, X, Xstable)
#     166         Vnorm0 = gradV ** 2
#     167         Vnorm = torch.zeros(V.shape,dtype=dtype,device=self.device)
# --> 168         Vnorm[:,0] = Vnorm0[:,0]+Vnorm0[:,1]
#     169         fh_V_mul0 = torch.mul(f_hat,gradV)
#     170         fh_V_mul = torch.zeros(V.shape,dtype=dtype,device=self.device)
#
# KeyboardInterrupt:

# %%
#optimization for Euclidean regularizer
#mode 0: exp barrier, 2: relu squared
loss_mat = optim_.optim_Euc_reg(q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, learning_rate = 1e-3,epoch=100, batch_size = 40,penalty_mode = 0)
# Out:
#  epoch = 20 i = 77, loss = 5613.065, total_loss = 5615.753, loss_b = 0.0, loss_t = 0.06424581, loss_reg = 40.08749, loss_reg_total =  34.352314           .....     ......
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f785c9be4b2c> in <module>
#       1 #optimization for Euclidean regularizer
#       2 #mode 0: exp barrier, 2: relu squared
# ----> 3 loss_mat = optim_.optim_Euc_reg(q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, learning_rate = 1e-3,epoch=100, batch_size = 40,penalty_mode = 0)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_Euc_reg(self, q_in_reg, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, penalty, penalty_boundary, learning_rate, epoch, batch_size, penalty_mode)
#     354
#     355                 #print(loss)
# --> 356                 loss.backward(retain_graph=True)
#     357                 optimizer.step()
#     358                 q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
nq1_p = 100
nq2_p = 100
nx1 = 100
nx2 = 100
xmin = [-robot.l1-robot.l2, -robot.l2]
xmax = [robot.l1+robot.l2,robot.l1+robot.l2]
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)

# %%
plt_.plot_f('fplot_Ereg_intro.png', 2, 0.5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_Ereg.png', robot, 2, 0.5, 1, quiver = False, streamplot = True, cmax=5)

# %%
plt_.cal_f()
fnumpy = plt_.f_total.detach()
#xtraj = robot.task_trajectory(robot.xinit, robot.xfinal, robot.T, robot.delta, robot.num_timesteps)
theta = np.linspace(0,2*math.pi,num = 100)
x_r1 = (l1-l2)*np.cos(theta)
y_r1 = (l1-l2)*np.sin(theta)
x_r2 = (l1+l2)*np.cos(theta)
y_r2 = (l1+l2)*np.sin(theta)
if (l1-l2)>0:
    plt.plot(x_r1,y_r1,'--b')
plt.plot(x_r2,y_r2,'--b')
plt.rcParams["figure.figsize"] = (10,10)
plt.plot(robot.xinit.numpy(),robot.xfinal.numpy(),'g')
#x1_mesh,x2_mesh = torch.meshgrid(xtraj[0,:],xtraj[1,:])
#widths = 0.002
plt.axis([-(l1+l2), (l1+l2), -(l1+l2), (l1+l2)])
#plt.quiver(xtraj[0,:],xtraj[1,:],x_dot[0,:],x_dot[1,:],width=0.003)
#plt.savefig('x.png',dpi = 200)

q1_mesh = plt_.q1_mesh
q2_mesh = plt_.q2_mesh
x1_mesh = np.zeros(q1_mesh.shape)
x2_mesh = np.zeros(q1_mesh.shape)
x_1_dot = np.zeros(q1_mesh.shape)
x_2_dot = np.zeros(q1_mesh.shape)

for i in range(q1_mesh.shape[0]):
    for j in range(q1_mesh.shape[1]):
        temp = robot.forward_kinematics([q1_mesh[i,j],q2_mesh[i,j]])
        temp2 = np.matmul(robot.get_jacobian([q1_mesh[i,j],q2_mesh[i,j]]),fnumpy[i,j,:])
        x1_mesh[i,j] = temp[0]
        x2_mesh[i,j] = temp[1]
        x_1_dot[i,j] = temp2[0]
        x_2_dot[i,j] = temp2[1]

plt.quiver(x1_mesh,x2_mesh,x_1_dot,x_2_dot,color = 'r',width=0.002)
#plt.streamplot(x1_mesh,x2_mesh,x_1_dot,x_2_dot,density = 3)#,
                       #color = np.log(x_1_dot*x_1_dot+x_2_dot*x_2_dot))

# %%
q1_mesh = plt_.q1_mesh
q2_mesh = plt_.q2_mesh
x1_mesh = np.zeros(q1_mesh.shape)
x2_mseh = np.zeros(q2_mesh.shape)

for i in range(q1_mesh.shape[0]):
    for j in range(q1_mesh.shape[1]):
        temp = robot.forward_kinematics([q1_mesh[i,j],q2_mesh[i,j]])
        x1_mesh[i,j] = temp[0]
        x2_mseh[i,j] = temp[1]

# %%
plt_.plot_fhat('fhatplot.png', quiver = False, streamplot = True)

# %%
plt_.plot_V('Vplot.png')
