# %%
import torch
import torch.nn as nn
import numpy as np
import random                                                                  
import matplotlib.pyplot as plt
torch.backends.cudnn.deterministic=True
from torch.nn import functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import math
from torch.autograd import grad
from Libraries import robotarm as ra
from Libraries import ICNN_net as net
from Libraries import ICNN_plot as pl
from Libraries import ICNN_optim_exp_barrier as opt
dtype = torch.float
device_c = torch.device("cpu")
device = torch.device("cuda:0")

# %%
#robot initialize
l1 = 3 
l2 = 2
m1 = 3
m2 = 4
robot = ra.robotarm(l1,l2,m1,m2,device)
xinit = torch.tensor([[-2],[2]],dtype=dtype)
#xinit = torch.tensor([[0],[3]],dtype=dtype)
xfinal = torch.tensor([[3],[3]],dtype=dtype)
#xinit = torch.tensor([[-3],[0]],dtype=dtype)
#xfinal = torch.tensor([[3],[2.5]],dtype=dtype)
T = 3
delta = 0.6
num_timesteps = 100
rmin,rmax,qmin,qmax,dt,qinit,qfinal,Xstable,xtraj,x_dot,qtraj,q_dot = robot.Initialize(xinit,xfinal,T,delta,num_timesteps)
#qtraj = qtraj[:,0:90]
#q_dot = q_dot[:,0:90]


#ICNN initialize
V_hidden_sizes = [200, 200,200,200]
fhat_hidden_sizes = [200,200,200,200,200,200,200,200,200]
tol = 0.01
alpha = 0.01
#model = net.ICNN_net( V_hidden_sizes, fhat_hidden_sizes,tol,alpha)

# %%
#print((x_dot**2)[0,:]+(x_dot**2)[1,:])
#print(x_dot)
# Out:
# tensor([[1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231,
#          1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231,
#          1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231,
#          1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231,
#          1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231,
#          1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231,
#          1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9231, 1.9228, 1.9204, 1.9156,
#          1.9084, 1.8987, 1.8867, 1.8723, 1.8555, 1.8362, 1.8146, 1.7906, 1.7641,
#          1.7353, 1.7040, 1.6704, 1.6343, 1.5959, 1.5550, 1.5117, 1.4660, 1.4180,
#          1.3675, 1.3146, 1.2593, 1.2016, 1.1415, 1.0790, 1.0141, 0.9468, 0.8771,
#          0.8050, 0.7305, 0.6535, 0.5742, 0.4925, 0.4084, 0.3218, 0.2329, 0.1415,
#          0.0478],
#         [0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846,
#          0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846,
#          0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846,
#          0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846,
#          0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846,
#          0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846,
#          0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3846, 0.3841, 0.3831,
#          0.3817, 0.3797, 0.3773, 0.3745, 0.3711, 0.3672, 0.3629, 0.3581, 0.3528,
#          0.3471, 0.3408, 0.3341, 0.3269, 0.3192, 0.3110, 0.3023, 0.2932, 0.2836,
#          0.2735, 0.2629, 0.2519, 0.2403, 0.2283, 0.2158, 0.2028, 0.1894, 0.1754,
#          0.1610, 0.1461, 0.1307, 0.1148, 0.0985, 0.0817, 0.0644, 0.0466, 0.0283,
#          0.0096]])

# %%
###################################################################
#getting grid data (for the regularizer)
nq1 = 100 # grid number
nq2 = 100 
nq1_b = 10 # grid number
nq2_b = 10
penalty = 1000
penalty_boundary = 100000
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device) #qmin, qmax는 위에서 구함
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)
q_in_boundary,q_dot_boundary = optim_.get_boundary(nq1_b,nq2_b,qmin,qmax)

# %%
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-2 ,epoch=2000)
# Out:
#  epoch = 409, loss = 0.00041238757, loss_b = 0.0, loss_t = 0.00041238757                    .       .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-27e8f1bd90b0> in <module>
# ----> 1 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-2 ,epoch=2000)
#
# ~/iPython_Notebook_Program/LeeByeongho/Harmonic_Regularizer/Harmonic_Regularization/Libraries/ICNN_optim_exp_barrier.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     152
#     153
# --> 154             qdot_pred = self.model.f_forward(q_in,self.Xstable).to(self.device)
#     155             loss_traj = dt*loss_fn(qdot_pred,qdot_real).to(self.device)
#     156
#
# ~/iPython_Notebook_Program/LeeByeongho/Harmonic_Regularizer/Harmonic_Regularization/Libraries/ICNN_net.py in f_forward(self, X, Xstable)
#     139
#     140     def f_forward(self, X, Xstable):
# --> 141         V = self.V_forward(X, Xstable)
#     142         f_hat = self.fhat_forward(X)
#     143         f = torch.zeros(f_hat.shape)
#
# ~/iPython_Notebook_Program/LeeByeongho/Harmonic_Regularizer/Harmonic_Regularization/Libraries/ICNN_net.py in V_forward(self, X, Xstable)
#     106
#     107         Vsum_pre = self.tol*((X-Xstable) ** 2)
# --> 108         Xst = torch.zeros(X.shape).to(self.device)
#     109         Vsum = torch.zeros(X.shape[0],1).to(self.device)
#     110         Vsum[:,0] = (Vsum_pre[:,0]+Vsum_pre[:,1])
#
# KeyboardInterrupt:

# %%
optim_.optim_Kinematic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 1e-3,epoch=150, batch_size = 100)
# Out:
#  epoch = 6 i = 14, loss = 1009.0549, total_loss = 1038.91, loss_b = 0.0, loss_t = 0.0065229842, loss_reg = 9.054889, loss_reg_total =  38.90998           .        .  . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b90abb2fe8f2> in <module>
# ----> 1 optim_.optim_Kinematic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 1e-3,epoch=150, batch_size = 100)
#
# ~/iPython_Notebook_Program/LeeByeongho/Harmonic_Regularizer/Harmonic_Regularization/Libraries/ICNN_optim_exp_barrier.py in optim_Kinematic_reg(self, robot, q_in_reg, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, penalty, penalty_boundary, Xstable, learning_rate, epoch, batch_size)
#     347                     Matrix_f[2*k:2*(k+1),:] = torch.reshape(current_output[:,k],[2,1])
#     348                     Matrix_G[2*k:2*(k+1),2*k:2*(k+1)] = Temp2
# --> 349                     Matrix_det_G[2*k:2*(k+1),2*k:2*(k+1)] = torch.sqrt(torch.det(Temp2))*torch.eye(2)
#     350                 ######################################
#     351                 Matrix_G_inv = torch.inverse(Matrix_G)
#
# KeyboardInterrupt:

# %%
nq1_p = 100
nq2_p = 100
nx1 = 100
nx2 = 100
xmin = [-robot.l1-robot.l2, -robot.l2]
xmax = [robot.l1+robot.l2,robot.l1+robot.l2]
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)

# %%
plt_.plot_f('fplot.png', 2, 2, .1, quiver = False, streamplot = True,cmax=2)

# %%
plt_.plot_f_taskspace('task_plot.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=3)

# %%
plt_.plot_V
