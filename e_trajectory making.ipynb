# %%
import torch
import torch.nn as nn
import numpy as np
import random                                                                  
import matplotlib.pyplot as plt
torch.backends.cudnn.deterministic=True
from torch.nn import functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import math
from torch.autograd import grad
from Libraries import robotarm as ra
from Libraries import ICNN_net as net
from Libraries import ICNN_plot as pl
from Libraries import ICNN_optim_custom_penalty as opt
dtype = torch.float
device_c = torch.device("cpu")
device = torch.device("cuda:0")

# %%
##setting number 1
#xpoints = np.array([   -2,  -3,  -1,  0 ,1,  2])
#ypoints = np.array([   1 ,   2,   3,  2 ,3,  3])
#xtraj = torch.tensor([xpoints,ypoints],dtype=dtype)
###print(xtraj)
#a = robot.config_trajectory(xtraj)
#xpoints = np.array(a[0,:])
#ypoints = np.array(a[1,:])
#print(xpoints,ypoints)

xpoints = np.array([1.9482175,1.9655874,1.2334888,0.84806216,0.5899877 ,1.39479113])
ypoints = np.array([2.300524 ,1.5707964,1.8234766,2.4188585 , 1.8234766,1.1707964])

xpoints = np.array([1.9482175,1.9655874,1.2334888,0.84806216,0.5899877 ,0.39479113])
ypoints = np.array([2.300524 ,1.5707964,1.8234766,2.4188585 , 1.8234766,1.5707964])

# %%
#setting number 2 (별로)
xpoints = np.array([  2.5,1.5,1 ,1.5,2.5])
ypoints = np.array([  0.5,1  ,1.5,2  ,2.5])

# %%
#setting number 3
xpoints = np.array([  2.5,2,2.2 ,2.5,2.6])
ypoints = np.array([  1,1.2,2,1.7,2.5])

# %%
#setting number 4
xpoints = np.array([  1.0,0.6,0.5,0.6,1.0])
ypoints = np.array([  1.5,1.7,1.9,2.3,2.6])

# %%
#setting number 5 약간 꼬불꼬불?
xpoints = np.array([  0.5,1.5,2.0,1.5,1.0,2.0])
ypoints = np.array([  0.5,0.8,1.1,1.4,1.7,2.0])

# %%
#robot initialize
l1 = 3 
l2 = 2
m1 = 3
m2 = 4
robot = ra.robotarm(l1,l2,m1,m2,device)
xinit = torch.tensor([[-2],[2]],dtype=dtype)
#xinit = torch.tensor([[0],[3]],dtype=dtype)
xfinal = torch.tensor([[3],[3]],dtype=dtype)
#xinit = torch.tensor([[-3],[0]],dtype=dtype)
#xfinal = torch.tensor([[3],[2.5]],dtype=dtype)
Vpoints = np.array([1.5,1.7,1.9,2.3,2.6])
T = 5
delta = 0.6
num_timesteps = 100
#xpoints = np.array([  2.5,1.5,1 ,1.5,2.5])
#ypoints = np.array([  0.5,1  ,1.5,2  ,2.5])
#rmin,rmax,qmin,qmax,dt,qinit,qfinal,Xstable,xtraj,x_dot,qtraj,q_dot = robot.Initialize(xinit,xfinal,T,delta,num_timesteps)
rmin,rmax,qmin,qmax,dt,qinit,qfinal,Xstable,xtraj,qtraj,q_dot = robot.Initialize_spline(xpoints,ypoints,Vpoints, T, delta, num_timesteps)

#ICNN initialize
fhat_size = 500
V_size = 200
V_hidden_sizes = [V_size, V_size,V_size,V_size]
fhat_hidden_sizes = [fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size,fhat_size]
tol = 0.01
alpha = 0.01
#getting grid data (for the regularizer)
nq1 = 100 # grid number
nq2 = 100 
nq1_b = 10 # grid number
nq2_b = 10
penalty = 5000
penalty_boundary = 100000
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device) #qmin, qmax는 위에서 구함
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)
q_in_boundary,q_dot_boundary = optim_.get_boundary(nq1_b,nq2_b,qmin,qmax)
nq1_p = 100
nq2_p = 100
nx1 = 100
nx2 = 100
xmin = [-robot.l1-robot.l2, -robot.l2]
xmax = [robot.l1+robot.l2,robot.l1+robot.l2]

# %%
a = q_dot**2
b = np.sqrt(a[0,:]+a[1,:])
time = np.linspace(0,T,100)
plt.plot(time,b)

# %% [markdown]
# # Ploting trajectory

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_q_traj('qtraj.png')

# %%
theta1 = xpoints[2]
theta2 = ypoints[2]
plt_.plot_robot_taskspace('robotplot.png', robot,theta1,theta2, traj=True)

# %% [markdown]
# # No Regularization

# %%
# initialize
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 10000, loss = 0.0012873751, loss_b = 0.0, loss_t = 0.0012873751                    .       ....

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0313_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0313_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# ## weight norm decay

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
# Out:
#  epoch = 7606, loss = 0.0019789594, loss_b = 0.0012077518, loss_t = 0.0019775007                    .....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-8186a0ffa40f> in <module>
#       1 #####################################################################
#       2 #weight regularization
# ----> 3 optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_weight_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch, weight_decay)
#     221             #loss_mat[t] = loss_boundary.data
#     222             print ('\r epoch = '+str(t+1)+ ', loss = '
# --> 223                        +str(ld.data.numpy()) +', loss_b = '+str(loss_boundary.to(device_c).data.numpy())+
#     224                    ', loss_t = '+str(loss_traj.to(device_c).data.numpy())+'                    .', end = ' ')
#     225
#
# C:\ProgramData\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write(self, text)
#      39
#      40     def write(self, text):
# ---> 41         self.__convertor.write(text)
#      42
#      43     def isatty(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write(self, text)
#     160     def write(self, text):
#     161         if self.strip or self.convert:
# --> 162             self.write_and_convert(text)
#     163         else:
#     164             self.wrapped.write(text)
#
# C:\ProgramData\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write_and_convert(self, text)
#     188             self.convert_ansi(*match.groups())
#     189             cursor = end
# --> 190         self.write_plain_text(text, cursor, len(text))
#     191
#     192
#
# C:\ProgramData\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write_plain_text(self, text, start, end)
#     194         if start < end:
#     195             self.wrapped.write(text[start:end])
# --> 196             self.wrapped.flush()
#     197
#     198
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in flush(self)
#     349                 self.pub_thread.schedule(evt.set)
#     350                 # and give a timeout to avoid
# --> 351                 if not evt.wait(self.flush_timeout):
#     352                     # write directly to __stderr__ instead of warning because
#     353                     # if this is happening sys.stderr may be the problem.
#
# C:\ProgramData\Anaconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# C:\ProgramData\Anaconda3\lib\threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0313_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0313_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# # Euclidean Regularization

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 1745, loss = 0.0031296122, loss_b = 0.0, loss_t = 0.0031296122                    .    .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-954352254adf> in <module>
#       1 #no regularization
# ----> 2 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     168
#     169
# --> 170             qdot_pred = self.model.f_forward(q_in,self.Xstable).to(self.device)
#     171             loss_traj = dt*loss_fn(qdot_pred,qdot_real).to(self.device)
#     172
#
# ~\Harmonic_Regularization\Libraries\ICNN_net.py in f_forward(self, X, Xstable)
#     163
#     164         Vsum = torch.sum(torch.sum(V))
# --> 165         gradV = grad(Vsum,X,create_graph=True,retain_graph=True)[0]
#     166         Vnorm0 = gradV ** 2
#     167         Vnorm = torch.zeros(V.shape,dtype=dtype,device=self.device)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     155     return Variable._execution_engine.run_backward(
#     156         outputs, grad_outputs, retain_graph, create_graph,
# --> 157         inputs, allow_unused)
#     158
#     159
#
# KeyboardInterrupt:

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-4 ,epoch=10000,weight_decay = 1e-4)
# Out:
#  epoch = 1262, loss = 0.008258733, loss_b = 0.0, loss_t = 0.008258733                    .        ....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-e0dee57ac97f> in <module>
#       1 #####################################################################
#       2 #weight regularization
# ----> 3 optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-4 ,epoch=10000,weight_decay = 1e-4)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_weight_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch, weight_decay)
#     211
#     212             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 213             loss.backward(retain_graph=True)
#     214             optimizer.step()
#     215             q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
#optimization for Euclidean regularizer
#mode 0: exp barrier, 1: relu squared
mode = 2
optim_.optim_Euc_reg(q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, learning_rate = 3e-5,epoch=100, batch_size = 40,penalty_mode = mode)
# Out:
#  epoch = 29 i = 22, loss = 5780.475, total_loss = 5791.9614, loss_b = 0.0, loss_t = 0.00015287747, loss_reg = 20.187344, loss_reg_total =  31.672123           ...      .. .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-893c892001cc> in <module>
#       2 #mode 0: exp barrier, 1: relu squared
#       3 mode = 2
# ----> 4 optim_.optim_Euc_reg(q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, learning_rate = 3e-5,epoch=100, batch_size = 40,penalty_mode = mode)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_Euc_reg(self, q_in_reg, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, penalty, penalty_boundary, learning_rate, epoch, batch_size, penalty_mode)
#     356                 loss = loss_reg+penalty*(self.penalty_fun(loss_task,eps,epoch,mode = penalty_mode))+penalty_boundary*((loss_boundary)**2)
#     357
# --> 358                 #print(loss)
#     359                 loss.backward(retain_graph=True)
#     360                 optimizer.step()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# # Kinematic Regularization

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 10000, loss = 0.008555868, loss_b = 0.0, loss_t = 0.008555868                    ..       ..

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-4 ,epoch=1000,weight_decay = 1e-4)
# Out:
#  epoch = 1000, loss = 0.008303485, loss_b = 0.0, loss_t = 0.008303485                    .        ..

# %%
#optimization for Euclidean regularizer
#mode 0: exp barrier, 1: relu squared
optim_.optim_Kinematic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 3e-5,epoch=150, batch_size = 40,penalty_mode = 2)
# Out:
#  epoch = 11 i = 68, loss = 5770.0225, total_loss = 5772.1826, loss_b = 0.0, loss_t = 0.00012684547, loss_reg = 10.386322, loss_reg_total =  12.549427           .        . ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-baed73f63aa7> in <module>
#       1 #optimization for Euclidean regularizer
#       2 #mode 0: exp barrier, 1: relu squared
# ----> 3 optim_.optim_Kinematic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 3e-5,epoch=150, batch_size = 40,penalty_mode = 2)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_Kinematic_reg(self, robot, q_in_reg, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, penalty, penalty_boundary, Xstable, learning_rate, epoch, batch_size, penalty_mode)
#     499                 #penalty = 10000                             ##########################################################################
#     500                 eps = 0.1
# --> 501                 loss = loss_reg+penalty*(self.penalty_fun(loss_task,eps,epoch,mode = penalty_mode))+penalty_boundary*((loss_boundary)**2)
#     502                 loss.backward(retain_graph=True)
#     503                 optimizer.step()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %% [markdown]
# # Kinetic Regularization

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)

# %%
#no regularization
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 601, loss = 0.010977829, loss_b = 0.0, loss_t = 0.010977829                    .         . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-954352254adf> in <module>
#       1 #no regularization
# ----> 2 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     170
#     171             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 172             loss.backward(retain_graph=True)
#     173             optimizer.step()
#     174             q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
#####################################################################
#weight regularization
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
# Out:
#  epoch = 762, loss = 0.001972202, loss_b = 0.0, loss_t = 0.001972202                    . .         ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-8186a0ffa40f> in <module>
#       1 #####################################################################
#       2 #weight regularization
# ----> 3 optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_weight_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch, weight_decay)
#     209
#     210             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 211             loss.backward(retain_graph=True)
#     212             optimizer.step()
#     213             q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
#optimization for Euclidean regularizer
#mode 0: exp barrier, 1: relu squared
optim_.optim_Kinetic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 1e-3,epoch=100, batch_size = 40,penalty_mode = 0)
# Out:
#  epoch = 2 i = 235, loss = 10073.9, total_loss = 10169.448, loss_b = 0.0, loss_t = 0.010491258, loss_reg = 64.07019, loss_reg_total =  160.68343           .  ..        ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-3dcad2826d60> in <module>
#       1 #optimization for Euclidean regularizer
#       2 #mode 0: exp barrier, 1: relu squared
# ----> 3 optim_.optim_Kinetic_reg(robot, q_in_reg,qtraj ,q_dot,dt,q_in_boundary,q_dot_boundary,penalty,penalty_boundary, Xstable, learning_rate = 1e-3,epoch=100, batch_size = 40,penalty_mode = 0)
#
# ~\Harmonic_Regularization\Libraries\ICNN_optim_custom_penalty.py in optim_Kinetic_reg(self, robot, q_in_reg, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, penalty, penalty_boundary, Xstable, learning_rate, epoch, batch_size, penalty_mode)
#     650                 loss = loss_reg+penalty*(self.penalty_fun(loss_task,mode = penalty_mode))+penalty_boundary*((loss_boundary)**2)
#     651                 #print(loss)
# --> 652                 loss.backward(retain_graph=True)
#     653                 optimizer.step()
#     654                 q_in.grad.zero_()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %%
nq1_p = 100
nq2_p = 100
nx1 = 100
nx2 = 100
xmin = [-robot.l1-robot.l2, -robot.l2]
xmax = [robot.l1+robot.l2,robot.l1+robot.l2]
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)

# %%
plt_.plot_f('fplot_noreg_0306_1.png', 2, .5, 1, quiver = False, streamplot = True,cmax=5)

# %%
plt_.plot_f_taskspace('task_plot_0306_1.png', robot, 2,  0.5,  1, quiver = False, streamplot = True,cmax=5)

# %%
# initialization
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device)

# %%
plt_.plot_V('t.png',3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8ea4d4481998> in <module>
# ----> 1 plt_.plot_V('t.png',3)
#
# ~\Harmonic_Regularization\Libraries\ICNN_plot.py in plot_V(self, filename, num_level)
#     295     def plot_V(self, filename,num_level):
#     296         pi = math.pi
# --> 297         V_total = self.cal_V()
#     298
#     299
#
# ~\Harmonic_Regularization\Libraries\ICNN_plot.py in cal_V(self)
#     148         Xlong = self.qmesh.view(-1,2).to(self.device)
#     149         Xlong.requires_grad=True
# --> 150         V_long = self.model.fh_forward(Xlong, self.Xstable)
#     151         V_total = V_long.view(self.nq1,self.nq2).to(device_c).detach()
#     152         #for i in range(self.nq1):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#     583                 return modules[name]
#     584         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 585             type(self).__name__, name))
#     586
#     587     def __setattr__(self, name, value):
#
# AttributeError: 'ICNN_net' object has no attribute 'fh_forward'
