# %%
import torch
import torch.nn as nn
import numpy as np
import random                                                                  
import matplotlib.pyplot as plt
torch.backends.cudnn.deterministic=True
from torch.nn import functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import math
from torch.autograd import grad
from Libraries import robotarm as ra
from Libraries import ICNN_net as netZ
from Libraries import ICNN_plot as pl
from Libraries import ICNN_optim_exp_barrier as opt
dtype = torch.float
device_c = torch.device("cpu")
device = torch.device("cuda:0")

# %%
#robot initialize
l1 = 3 
l2 = 2
m1 = 3
m2 = 4
robot = ra.robotarm(l1,l2,m1,m2,device)
xinit = torch.tensor([[-3],[1]],dtype=dtype)
xfinal = torch.tensor([[2],[3]],dtype=dtype)
#xinit = torch.tensor([[-3],[0]],dtype=dtype)
#xfinal = torch.tensor([[3],[2.5]],dtype=dtype)
T = 5
delta = 0.6
num_timesteps = 100
rmin,rmax,qmin,qmax,dt,qinit,qfinal,Xstable,xtraj,x_dot,qtraj,q_dot = robot.Initialize(xinit,xfinal,T,delta,num_timesteps)
#print(max_speed)

#spline adopting

xpoints = np.array([   -2,  -3,  -1,  0 ,1,  2])
ypoints = np.array([   1 ,   2,   3,  2 ,3,  3])
xtraj,x_dot = robot.spline_traj(xpoints,ypoints, T, delta, num_timesteps)
qtraj = robot.config_trajectory(xtraj)
q_dot = robot.config_velocity(qtraj,x_dot)

#ICNN initialize
V_hidden_sizes = [200, 200,200,200]
fhat_hidden_sizes = [1000,1000,1000,1000,1000]
tol = 0.01
alpha = 0.1
#model = net.ICNN_net( V_hidden_sizes, fhat_hidden_sizes,tol,alpha)

# %%
#optimization

#getting grid data (for the regularizer)
nq1 = 100 # grid number
nq2 = 100 
nq1_b = 10 # grid number
nq2_b = 10
penalty = 50000
penalty_boundary = 10000
optim_ = opt.ICNN_optim(V_hidden_sizes, fhat_hidden_sizes,tol,alpha,Xstable,device) #qmin, qmax는 위에서 구함
q_in_reg,q1,q2 = optim_.get_grid(nq1,nq2,qmin,qmax)
q_in_boundary,q_dot_boundary = optim_.get_boundary(nq1_b,nq2_b,qmin,qmax)

# %%
optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
# Out:
#  epoch = 639, loss = 0.007802208, loss_b = 0.0, loss_t = 0.007802208                    . .   . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e694a5401bcc> in <module>
# ----> 1 optim_.optim_no_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000)
#
# ~/iPython_Notebook_Program/LeeByeongho/Harmonic_Regularizer/Harmonic_Regularization/Libraries/ICNN_optim_exp_barrier.py in optim_no_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch)
#     156
#     157             loss = loss_traj+penalty_boundary*((loss_boundary)**2)
# --> 158             loss.backward(retain_graph=True)
#     159             optimizer.step()
#     160             q_in.grad.zero_()
#
# ~/anaconda3/envs/py3_bhl/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/anaconda3/envs/py3_bhl/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
# Out:
#  epoch = 619, loss = 0.00903524, loss_b = 0.0, loss_t = 0.00903524                    . .        .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ebe9f40e267f> in <module>
# ----> 1 optim_.optim_weight_reg(qtraj,q_dot,dt,q_in_boundary,q_dot_boundary, learning_rate = 1e-3 ,epoch=10000,weight_decay = 1e-4)
#
# ~/iPython_Notebook_Program/LeeByeongho/Harmonic_Regularizer/Harmonic_Regularization/Libraries/ICNN_optim_exp_barrier.py in optim_weight_reg(self, qtraj, q_dot, dt, q_in_boundary, q_dot_boundary, learning_rate, epoch, weight_decay)
#     183         for t in range(epoch):
#     184
# --> 185             qdot_bound_pred = self.model.f_forward(q_in_boundary,self.Xstable).to(self.device)
#     186             temp0_boundary = torch.sqrt((qdot_bound_pred**2)[:,0]+(qdot_bound_pred**2)[:,1])
#     187             temp_boundary = torch.mul(q_dot_boundary,qdot_bound_pred)
#
# ~/iPython_Notebook_Program/LeeByeongho/Harmonic_Regularizer/Harmonic_Regularization/Libraries/ICNN_net.py in f_forward(self, X, Xstable)
#     145
#     146         Vsum = torch.sum(torch.sum(V))
# --> 147         gradV = grad(Vsum,X,create_graph=True,retain_graph=True)[0]
#     148         Vnorm0 = gradV ** 2
#     149         Vnorm = torch.zeros(V.shape,dtype=dtype,device=self.device)
#
# ~/anaconda3/envs/py3_bhl/lib/python3.6/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     155     return Variable._execution_engine.run_backward(
#     156         outputs, grad_outputs, retain_graph, create_graph,
# --> 157         inputs, allow_unused)
#     158
#     159
#
# KeyboardInterrupt:

# %%
nq1_p = 100
nq2_p = 100
nx1 = 100
nx2 = 100
xmin = [-robot.l1-robot.l2, -robot.l2]
xmax = [robot.l1+robot.l2,robot.l1+robot.l2]
plt_ = pl.ICNN_plot(optim_.model,qmin,qmax,nq1_p,nq2_p,xmin,xmax,nx1,nx2,Xstable,qtraj,xtraj,l1,l2,device)

# %%
plt_.plot_f('fplot_wreg.png', 2, 0.5, 1, quiver = False, streamplot = True)

# %%
plt_.plot_f_taskspace('task_plot_wreg.png', robot, 2, 0.5, 1, quiver = False, streamplot = True)

# %%
plt_.cal_f()
fnumpy = plt_.f_total.detach()
#xtraj = robot.task_trajectory(robot.xinit, robot.xfinal, robot.T, robot.delta, robot.num_timesteps)
theta = np.linspace(0,2*math.pi,num = 100)
x_r1 = (l1-l2)*np.cos(theta)
y_r1 = (l1-l2)*np.sin(theta)
x_r2 = (l1+l2)*np.cos(theta)
y_r2 = (l1+l2)*np.sin(theta)
x_r3 = (l2)*np.cos(theta)+l1
y_r3 = (l2)*np.abs(np.sin(theta))
x_r4 = (l2)*np.cos(theta)-l1
y_r4 = -(l2)*np.abs(np.sin(theta))
if (l1-l2)>0:
    plt.plot(x_r1,y_r1,'--b')
plt.plot(x_r2,y_r2,'--b')
plt.plot(x_r3,y_r3,'y')
plt.plot(x_r4,y_r4,'y')

plt.rcParams["figure.figsize"] = (15,15)
plt.plot((xinit.numpy()[0],xfinal.numpy()[0]),(xinit.numpy()[1],xfinal.numpy()[1]),'g')
#x1_mesh,x2_mesh = torch.meshgrid(xtraj[0,:],xtraj[1,:])
#widths = 0.002
plt.axis([-(l1+l2), (l1+l2), -(l1+l2), (l1+l2)])
#plt.quiver(xtraj[0,:],xtraj[1,:],x_dot[0,:],x_dot[1,:],width=0.003)
#plt.savefig('x.png',dpi = 200)

q1_mesh = plt_.q1_mesh
q2_mesh = plt_.q2_mesh
x1_mesh = np.zeros(q1_mesh.shape)
x2_mesh = np.zeros(q1_mesh.shape)
x_1_dot = np.zeros(q1_mesh.shape)
x_2_dot = np.zeros(q1_mesh.shape)

for i in range(q1_mesh.shape[0]):
    for j in range(q1_mesh.shape[1]):
        temp = robot.forward_kinematics([q1_mesh[i,j],q2_mesh[i,j]])
        temp2 = np.matmul(robot.get_jacobian([q1_mesh[i,j],q2_mesh[i,j]]),fnumpy[i,j,:])
        x1_mesh[i,j] = temp[0]
        x2_mesh[i,j] = temp[1]
        x_1_dot[i,j] = temp2[0]
        x_2_dot[i,j] = temp2[1]

plt.quiver(x1_mesh,x2_mesh,x_1_dot,x_2_dot,color = 'r',width=0.002)
#plt.streamplot(x1_mesh,x2_mesh,x_1_dot,x_2_dot,density = 3)#,
                       #color = np.log(x_1_dot*x_1_dot+x_2_dot*x_2_dot))

# %%
plt_.plot_fhat('fhatplot.png', quiver = False, streamplot = True)

# %%
plt_.plot_V('Vplot.png')
